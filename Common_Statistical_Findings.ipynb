# %%
#Common statistical analysis can go here

# %%
# %pip install numpy
# %pip install pandas
from IPython.display import clear_output

for i in range(10):
    clear_output(wait=True)
    print("Cleaned up the log!")
# Out:
# Cleaned up the log!

# %%
import numpy as np
import pandas as pd

# %%
#Reading the music data from CSV

df = pd.read_csv("data/dataset.csv")

columns_to_select = [
    "danceability",
    "energy",
    "key",
    "loudness",
    "mode",
    "speechiness",
    "acousticness",
    "instrumentalness",
    "liveness",
    "valence",
    "tempo",
    "time_signature"
]

df_filtered = df.drop_duplicates(subset=['id_x'])
df_filtered = df_filtered.dropna()
X = df_filtered[columns_to_select]
X.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  14538.000000  14538.000000  14538.000000  14538.000000  14538.000000
# mean       0.500034      0.350873      5.017609    -16.088508      0.662608
# std        0.208131      0.281672      3.505962      9.232804      0.472836
# min        0.000000      0.000020      0.000000    -47.898000      0.000000
# 25%        0.365000      0.095300      2.000000    -22.384750      0.000000
# 50%        0.532000      0.298000      5.000000    -13.488000      1.000000
# 75%        0.661000      0.557000      8.000000     -8.791000      1.000000
# max        0.982000      1.000000     11.000000     -0.776000      1.000000
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  14538.000000  14538.000000      14538.000000  14538.000000
# mean       0.065355      0.625812          0.503310      0.161407
# std        0.061485      0.364233          0.426330      0.144901
# min        0.000000      0.000000          0.000000      0.020500
# 25%        0.036200      0.258000          0.000194      0.099300
# 50%        0.045000      0.787000          0.727000      0.111000
# 75%        0.065000      0.954000          0.914000      0.144000
# max        0.709000      0.996000          1.000000      0.990000
#
#             valence         tempo  time_signature
# count  14538.000000  14538.000000    14538.000000
# mean       0.317894    110.055627        3.798253
# std        0.243971     31.808833        0.603997
# min        0.000000      0.000000        0.000000
# 25%        0.116000     83.022000        4.000000
# 50%        0.264000    108.388000        4.000000
# 75%        0.478000    130.339250        4.000000
# max        0.982000    224.536000        5.000000
