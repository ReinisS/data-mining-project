# %%
# "Data Mining" course Project
# Dimensionality reduction for Spotify music data

# Group 3:
# Athanasios Karampalis
# Reinis Sestakovskis
# Onur Yuksel

# 2022

# %%
# Read in secrets from secrets.json

import os
import json

secrets_filename = "secrets.json"

def read_secrets() -> dict:
    filename = os.path.join(secrets_filename)
    try:
        with open(filename, mode='r') as f:
            return json.loads(f.read())
    except FileNotFoundError:
        print(f"Could not find file {secrets_filename}!")
        return {}

secrets = read_secrets()

# %%
# Install necessary PIP packages

# %pip install numpy pandas spotipy tqdm
# Out:
# Requirement already satisfied: numpy in c:\users\reinis\appdata\roaming\python\python39\site-packages (1.21.4)
# Requirement already satisfied: pandas in c:\users\reinis\appdata\roaming\python\python39\site-packages (1.3.4)
# Requirement already satisfied: spotipy in c:\users\reinis\appdata\roaming\python\python39\site-packages (2.19.0)
# Requirement already satisfied: tqdm in c:\users\reinis\appdata\roaming\python\python39\site-packages (4.63.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\reinis\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\reinis\appdata\roaming\python\python39\site-packages (from pandas) (2021.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\reinis\appdata\roaming\python\python39\site-packages (from spotipy) (1.26.8)
# Requirement already satisfied: requests>=2.25.0 in c:\users\reinis\appdata\roaming\python\python39\site-packages (from spotipy) (2.27.1)
# Requirement already satisfied: six>=1.15.0 in c:\users\reinis\appdata\roaming\python\python39\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: colorama in c:\users\reinis\appdata\roaming\python\python39\site-packages (from tqdm) (0.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\reinis\appdata\roaming\python\python39\site-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\reinis\appdata\roaming\python\python39\site-packages (from requests>=2.25.0->spotipy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\reinis\appdata\roaming\python\python39\site-packages (from requests>=2.25.0->spotipy) (3.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.3; however, version 22.2.2 is available.
# You should consider upgrading via the 'c:\Users\Reinis\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# Use Spotipy for easier access to the Spotify API
# https://spotipy.readthedocs.io/
# https://github.com/plamere/spotipy

import spotipy
from spotipy.oauth2 import SpotifyOAuth

# scope = "user-library-read"

client_id = secrets["CLIENT_ID"]
client_secret = secrets["CLIENT_SECRET"]
redirect_url = secrets["REDIRECT_URI"]

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id, client_secret=client_secret, redirect_uri=redirect_url))

# %%
# Use tqdm to see a progress bar when loading the data
from tqdm import tqdm

# Use pandas for DataFrames
import pandas as pd

# %%
categories = []

for batch_start_index in tqdm(range(0, 150, 50)):
    categories_results = sp.categories(offset=batch_start_index, limit=50)
    if len(categories_results['categories']['items']) == 0:
        print('Found all categories, finishing early')
        break
    categories = categories + categories_results['categories']['items']
print(len(categories))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]Using `localhost` as redirect URI without a port. Specify a port (e.g. `localhost:8080`) to allow automatic retrieval of authentication code instead of having to copy and paste the URL your browser is redirected to.
#  33%|███▎      | 1/3 [00:15<00:31, 15.87s/it]
# Found all categories, finishing early
# 46

# %%
categories_df = pd.json_normalize(categories)
categories_df.to_csv(path_or_buf=os.path.join('./data', 'categories.csv'))
categories_df.tail(3)
# Out:
#                                                  href  \
# 43  https://api.spotify.com/v1/browse/categories/0...
# 44  https://api.spotify.com/v1/browse/categories/0...
# 45  https://api.spotify.com/v1/browse/categories/0...
#
#                                                 icons                      id  \
# 43  [{'height': None, 'url': 'https://t.scdn.co/im...  0JQ5DAqbMKFRNXsIvgZF9A
# 44  [{'height': None, 'url': 'https://t.scdn.co/im...  0JQ5DAqbMKFQ1UFISXj59F
# 45  [{'height': None, 'url': 'https://t.scdn.co/im...  0JQ5DAqbMKFLVaM30PMBm4
#
#             name
# 43  Music + Talk
# 44          Arab
# 45        Summer

# %%
mood_category_id = categories_df[categories_df['name'] == 'Mood'].iloc[0]['id']
print(mood_category_id)
# Out:
# 0JQ5DAqbMKFzHmL4tf05da

# %%
playlists = []

for batch_start_index in tqdm(range(0, 200, 50)):
    playlists_results = sp.category_playlists(category_id=mood_category_id, offset=batch_start_index, limit=50)
    if len(playlists_results['playlists']['items']) == 0:
        print('Found all playlists, finishing early')
        break
    playlists = playlists + playlists_results['playlists']['items']
print(len(playlists))
# Out:
#  75%|███████▌  | 3/4 [00:01<00:00,  2.82it/s]
# Found all playlists, finishing early
# 131

# %%
playlists_df = pd.json_normalize(playlists)
playlists_df.to_csv(path_or_buf=os.path.join('./data', 'playlists.csv'))
playlists_df.tail(3)
# Out:
#      collaborative                              description  \
# 128          False  The melancholic and soft sound of Jazz.
# 129          False              Beautifully sad piano music
# 130          False                        cry just a little
#
#                                                   href  \
# 128  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 129  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 130  https://api.spotify.com/v1/playlists/37i9dQZF1...
#
#                          id  \
# 128  37i9dQZF1DWWR73B3Bnjfh
# 129  37i9dQZF1DWZrc3lwvImLj
# 130  37i9dQZF1DWU4lunzhQdRx
#
#                                                 images  \
# 128  [{'height': None, 'url': 'https://i.scdn.co/im...
# 129  [{'height': None, 'url': 'https://i.scdn.co/im...
# 130  [{'height': None, 'url': 'https://i.scdn.co/im...
#
#                          name primary_color public  \
# 128                 Jazz Noir          None   None
# 129  Melancholy Instrumentals          None   None
# 130          sad girl country          None   None
#
#                                            snapshot_id      type  \
# 128  MTY2NDk3NzY4MiwwMDAwMDAwMGIyNThlNTEyNGViMmQ4MD...  playlist
# 129  MTY2MzkzOTkzNywwMDAwMDAwMDA1ZDYxYzgyMzAwZjA4Y2...  playlist
# 130  MTY2MzAzMDMwNSwwMDAwMDAwMGRkOWRkNjMzNDgwMjBlMD...  playlist
#
#                                          uri  \
# 128  spotify:playlist:37i9dQZF1DWWR73B3Bnjfh
# 129  spotify:playlist:37i9dQZF1DWZrc3lwvImLj
# 130  spotify:playlist:37i9dQZF1DWU4lunzhQdRx
#
#                                  external_urls.spotify owner.display_name  \
# 128  https://open.spotify.com/playlist/37i9dQZF1DWW...            Spotify
# 129  https://open.spotify.com/playlist/37i9dQZF1DWZ...            Spotify
# 130  https://open.spotify.com/playlist/37i9dQZF1DWU...            Spotify
#
#                owner.external_urls.spotify  \
# 128  https://open.spotify.com/user/spotify
# 129  https://open.spotify.com/user/spotify
# 130  https://open.spotify.com/user/spotify
#
#                                    owner.href owner.id owner.type  \
# 128  https://api.spotify.com/v1/users/spotify  spotify       user
# 129  https://api.spotify.com/v1/users/spotify  spotify       user
# 130  https://api.spotify.com/v1/users/spotify  spotify       user
#
#                 owner.uri                                        tracks.href  \
# 128  spotify:user:spotify  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 129  spotify:user:spotify  https://api.spotify.com/v1/playlists/37i9dQZF1...
# 130  spotify:user:spotify  https://api.spotify.com/v1/playlists/37i9dQZF1...
#
#      tracks.total
# 128           100
# 129           169
# 130            50

# %%
playlist_ids = playlists_df['id'].to_numpy()
print(playlist_ids[:5])
# Out:
# ['37i9dQZF1DX3rxVfibe1L0' '37i9dQZF1DWSf2RDTDayIx'
#  '37i9dQZF1DWSqmBTGDYngZ' '37i9dQZF1DX6VdMW310YC7'
#  '37i9dQZF1DXdPec7aLTmlC']

# %%
tracks = []

for playlist_id in tqdm(playlist_ids):
    for batch_start_index in range(0, 500, 50):
        track_results = sp.playlist_items(playlist_id=playlist_id, offset=batch_start_index, limit=50)
        if len(track_results['items']) == 0:
            # Found all tracks, finishing early for current playlist
            break
        # Add current playlist id to the current batch of tracks
        for track in track_results['items']:
            track['playlist_id'] = playlist_id
        tracks = tracks + track_results['items']
print(len(tracks))
# Out:
# 100%|██████████| 131/131 [02:17<00:00,  1.05s/it]
# 17860

# %%
tracks_df = pd.json_normalize(tracks)
# Drop tracks which have no id
tracks_df = tracks_df[tracks_df['track.id'].notna()]
print(len(tracks_df))
tracks_df = tracks_df.drop_duplicates(subset=['playlist_id', 'track.name', 'track.album.name', 'track.album.release_date'])
print(len(tracks_df))
tracks_df.to_csv(path_or_buf=os.path.join('./data', 'tracks.csv'))
tracks_df.tail(3)
# Out:
# 17856
# 16350
#                    added_at  is_local primary_color             playlist_id  \
# 17857  2022-09-13T00:51:45Z     False          None  37i9dQZF1DWU4lunzhQdRx
# 17858  2022-09-13T00:51:45Z     False          None  37i9dQZF1DWU4lunzhQdRx
# 17859  2022-09-13T00:51:45Z     False          None  37i9dQZF1DWU4lunzhQdRx
#
#        added_by.external_urls.spotify                      added_by.href  \
# 17857  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 17858  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
# 17859  https://open.spotify.com/user/  https://api.spotify.com/v1/users/
#
#       added_by.id added_by.type   added_by.uri track.album.album_type  ...  \
# 17857                      user  spotify:user:                  album  ...
# 17858                      user  spotify:user:                  album  ...
# 17859                      user  spotify:user:                  album  ...
#
#       track.show.id track.show.images track.show.is_externally_hosted  \
# 17857           NaN               NaN                             NaN
# 17858           NaN               NaN                             NaN
# 17859           NaN               NaN                             NaN
#
#       track.show.languages track.show.media_type track.show.name  \
# 17857                  NaN                   NaN             NaN
# 17858                  NaN                   NaN             NaN
# 17859                  NaN                   NaN             NaN
#
#       track.show.publisher track.show.total_episodes track.show.type  \
# 17857                  NaN                       NaN             NaN
# 17858                  NaN                       NaN             NaN
# 17859                  NaN                       NaN             NaN
#
#        track.show.uri
# 17857             NaN
# 17858             NaN
# 17859             NaN
#
# [3 rows x 69 columns]

# %%
# Retrieve track ids to a list
# These will be needed to retrieve the audio features from the Spotify API
track_ids = tracks_df['track.id'].tolist()
print(track_ids[:10])
# Out:
# ['6YIivt0G3ZUuNrM62jp9pL', '4MTmAFWHpvB9kPMSRgLFRp', '6y6xhAgZjvxy5kR5rigpY3', '4h9wh7iOZ0GGn8QVp4RAOB', '3o9kpgkIcffx0iSwxhuNI2', '1imMjt1YGNebtrtTAprKV7', '4svaKoxMMP7ImmKrD5hfQu', '0T5iIrXA4p5GsubkhuBIKV', '0zzVTGyRrWpQu8Fr28NRAv', '18XlJEroUwFo0tLZxscgXE']

# %%
# Retrieve audio features from the Spotify API
audio_features = []

for batch_start_index in tqdm(range(0, len(track_ids), 50)):
    audio_features_results = sp.audio_features(track_ids[batch_start_index:batch_start_index+50])
    audio_features = audio_features + audio_features_results
print(len(audio_features))
# Out:
# 100%|██████████| 327/327 [00:47<00:00,  6.90it/s]
# 16350

# %%
# Filter out non-object (non-dict) results (example: "None")
audio_features_filtered = [item for item in audio_features if isinstance(item, dict)]
print(len(audio_features_filtered))
# Out:
# 16269

# %%
# Convert to a Pandas dataframe and check what the data looks like
audio_features_df = pd.DataFrame(audio_features_filtered)
audio_features_df.to_csv(path_or_buf=os.path.join('./data', 'audio_features.csv'))
audio_features_df.tail(3)
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 16266         0.621   0.399    3    -6.807     0       0.0262        0.5940
# 16267         0.517   0.378    7    -6.982     1       0.0265        0.0995
# 16268         0.503   0.431    8    -8.171     1       0.0366        0.2750
#
#        instrumentalness  liveness  valence    tempo            type  \
# 16266          0.000000    0.1070    0.334   80.993  audio_features
# 16267          0.000011    0.0989    0.218  141.903  audio_features
# 16268          0.000024    0.1080    0.176  163.728  audio_features
#
#                            id                                   uri  \
# 16266  0VsDzurvIUoRNT4fIactL3  spotify:track:0VsDzurvIUoRNT4fIactL3
# 16267  69meckPoEWAVOUXjkp5ShS  spotify:track:69meckPoEWAVOUXjkp5ShS
# 16268  56DsYXpdqkl3t2G3xM8MtA  spotify:track:56DsYXpdqkl3t2G3xM8MtA
#
#                                               track_href  \
# 16266  https://api.spotify.com/v1/tracks/0VsDzurvIUoR...
# 16267  https://api.spotify.com/v1/tracks/69meckPoEWAV...
# 16268  https://api.spotify.com/v1/tracks/56DsYXpdqkl3...
#
#                                             analysis_url  duration_ms  \
# 16266  https://api.spotify.com/v1/audio-analysis/0VsD...       188853
# 16267  https://api.spotify.com/v1/audio-analysis/69me...       247447
# 16268  https://api.spotify.com/v1/audio-analysis/56Ds...       184760
#
#        time_signature
# 16266               4
# 16267               4
# 16268               3

# %%
# Merge the two track and the audio feature dataframes into one using the track ids
merged_df = pd.merge(audio_features_df, tracks_df, how='inner', left_on = 'id', right_on = 'track.id')
merged_df.tail(3)
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 20484         0.621   0.399    3    -6.807     0       0.0262        0.5940
# 20485         0.517   0.378    7    -6.982     1       0.0265        0.0995
# 20486         0.503   0.431    8    -8.171     1       0.0366        0.2750
#
#        instrumentalness  liveness  valence  ...  track.show.id  \
# 20484          0.000000    0.1070    0.334  ...            NaN
# 20485          0.000011    0.0989    0.218  ...            NaN
# 20486          0.000024    0.1080    0.176  ...            NaN
#
#       track.show.images track.show.is_externally_hosted track.show.languages  \
# 20484               NaN                             NaN                  NaN
# 20485               NaN                             NaN                  NaN
# 20486               NaN                             NaN                  NaN
#
#       track.show.media_type track.show.name  track.show.publisher  \
# 20484                   NaN             NaN                   NaN
# 20485                   NaN             NaN                   NaN
# 20486                   NaN             NaN                   NaN
#
#        track.show.total_episodes track.show.type  track.show.uri
# 20484                        NaN             NaN             NaN
# 20485                        NaN             NaN             NaN
# 20486                        NaN             NaN             NaN
#
# [3 rows x 87 columns]

# %%
# Merge with the playlist dataframe
merged_df = pd.merge(merged_df, playlists_df, how='inner', left_on = 'playlist_id', right_on = 'id')
merged_df.tail(3)
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 22358         0.611  0.2270    8   -12.682     1       0.0380         0.986
# 22359         0.356  0.0868    6   -15.106     0       0.0352         0.994
# 22360         0.243  0.2710   10   -15.593     1       0.0350         0.642
#
#        instrumentalness  liveness  valence  ...  \
# 22358           0.00126     0.102   0.2370  ...
# 22359           0.05980     0.103   0.0966  ...
# 22360           0.00116     0.275   0.3530  ...
#
#                                          uri_y  \
# 22358  spotify:playlist:37i9dQZF1DX70dqoLSWJrU
# 22359  spotify:playlist:37i9dQZF1DX70dqoLSWJrU
# 22360  spotify:playlist:37i9dQZF1DX70dqoLSWJrU
#
#                                    external_urls.spotify owner.display_name  \
# 22358  https://open.spotify.com/playlist/37i9dQZF1DX7...            Spotify
# 22359  https://open.spotify.com/playlist/37i9dQZF1DX7...            Spotify
# 22360  https://open.spotify.com/playlist/37i9dQZF1DX7...            Spotify
#
#                  owner.external_urls.spotify  \
# 22358  https://open.spotify.com/user/spotify
# 22359  https://open.spotify.com/user/spotify
# 22360  https://open.spotify.com/user/spotify
#
#                                      owner.href owner.id  owner.type  \
# 22358  https://api.spotify.com/v1/users/spotify  spotify        user
# 22359  https://api.spotify.com/v1/users/spotify  spotify        user
# 22360  https://api.spotify.com/v1/users/spotify  spotify        user
#
#                   owner.uri  \
# 22358  spotify:user:spotify
# 22359  spotify:user:spotify
# 22360  spotify:user:spotify
#
#                                              tracks.href  tracks.total
# 22358  https://api.spotify.com/v1/playlists/37i9dQZF1...           100
# 22359  https://api.spotify.com/v1/playlists/37i9dQZF1...           100
# 22360  https://api.spotify.com/v1/playlists/37i9dQZF1...           100
#
# [3 rows x 107 columns]

# %%
# Check the columns of our new dataframe
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22361 entries, 0 to 22360
# Columns: 107 entries, danceability to tracks.total
# dtypes: bool(2), float64(18), int64(5), object(82)
# memory usage: 18.1+ MB

# %%
# Select only needed columns

columns_to_select = [
    "id_x",             # Track id
    "track.artists",
    "track.name",
    "playlist_id",
    "name",             # Playlist name
    "danceability",
    "energy",
    "key",
    "loudness",
    "mode",
    "speechiness",
    "acousticness",
    "instrumentalness",
    "liveness",
    "valence",
    "tempo",
    "duration_ms",
    "time_signature",
    "track.popularity"
]

cleaned_df = merged_df[columns_to_select].drop_duplicates(subset=['id_x', 'playlist_id'])
print(len(cleaned_df))
print(cleaned_df.tail(3))
# Out:
# 16269
#                          id_x  \
# 22358  5wIXpK3BAW5geIlEmYf23n
# 22359  5sOGjH3QgwqhNRwT9I1nYl
# 22360  1ScLuFh6ZPY0bkSrv9uVMO
#
#                                            track.artists  \
# 22358  [{'external_urls': {'spotify': 'https://open.s...
# 22359  [{'external_urls': {'spotify': 'https://open.s...
# 22360  [{'external_urls': {'spotify': 'https://open.s...
#
#                                               track.name  \
# 22358                           When Your Lover Has Gone
# 22359                                    I Cried For You
# 22360  The End of a Love Affair - Mono Take 4 with Vo...
#
#                   playlist_id             name  danceability  energy  key  \
# 22358  37i9dQZF1DX70dqoLSWJrU  Heartbreak Jazz         0.611  0.2270    8
# 22359  37i9dQZF1DX70dqoLSWJrU  Heartbreak Jazz         0.356  0.0868    6
# 22360  37i9dQZF1DX70dqoLSWJrU  Heartbreak Jazz         0.243  0.2710   10
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 22358   -12.682     1       0.0380         0.986           0.00126     0.102
# 22359   -15.106     0       0.0352         0.994           0.05980     0.103
# 22360   -15.593     1       0.0350         0.642           0.00116     0.275
#
#        valence    tempo  duration_ms  time_signature  track.popularity
# 22358   0.2370  119.088       297867               4              25.0
# 22359   0.0966  111.557       208707               3              38.0
# 22360   0.3530   84.589       287960               4              41.0

# %%
# Convert the 'track.artists' column to just a list of artists' names

cleaned_df['track.artists'] = cleaned_df['track.artists'] \
    .map(lambda obj_list: ', '.join([obj['name'] for obj in obj_list]))

# %%
# Check that the "track.artists" column has been cleaned up
cleaned_df['track.artists'].head(20)
# Out:
# 0                                     AJR
# 4                           The Lumineers
# 8           Alesso, Marshmello, James Bay
# 12                            OneRepublic
# 18                             Em Beihold
# 22                               Dua Lipa
# 24                                    Jax
# 28                        Stephen Sanchez
# 32                Marshmello, Demi Lovato
# 36                               Maroon 5
# 38                              Rosa Linn
# 42                             Ed Sheeran
# 44                                FINNEAS
# 46          Lost Frequencies, Calum Scott
# 48                                  Adele
# 50                            George Ezra
# 52                     Alesso, Katy Perry
# 54                            OneRepublic
# 58       Hailee Steinfeld, Anderson .Paak
# 62    benny blanco, Marshmello, Vance Joy
# Name: track.artists, dtype: object

# %%
# Save the final dataframe to a CSV file
cleaned_df.to_csv(path_or_buf=os.path.join('./data', 'dataset.csv'))
